# %% [markdown]
# <a href="https://colab.research.google.com/github/fred2167/Personal-Project/blob/master/custom_dataset_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torchvision
import torchvision.transforms as transforms
from torch.utils.tensorboard import SummaryWriter
import matplotlib.pyplot as plt
import os
import time
import numpy as np

# %% [markdown]
# '''
# TODO:
# - same images in multiple classes
# '''

# %%
transformer = torchvision.transforms.Compose([transforms.Resize(256),
                                             transforms.CenterCrop(224),
                                             transforms.ToTensor(),
                                             transforms.Normalize((0.5,0.5,0.5),(0.5,0.5,0.5))
                                             ])
data = torchvision.datasets.ImageFolder('/home/fred/datasets/dataset100/UECFOOD100/', transform=transformer)
loader = torch.utils.data.DataLoader(data, batch_size=16, shuffle=True, num_workers=2, pin_memory=True)

# %%
def imshow(img):
    img = img /2 +0.5
    npimg = img.numpy()
    plt.figure(figsize=(20,10))
    plt.imshow(np.transpose(npimg,(1,2,0)))
    plt.show

dataiter = iter(loader)
images, label = dataiter.next()
imshow(torchvision.utils.make_grid(images))

# %%
data.class_to_idx
# Out:
# {'beef bowl': 0,
#  'beef curry': 1,
#  'beef noodle': 2,
#  'beef steak': 3,
#  'bibimbap': 4,
#  'boiled chicken and vegetables': 5,
#  'boiled fish': 6,
#  'cabbage roll': 7,
#  'chicken rice': 8,
#  "chicken-'n'-egg on rice": 9,
#  'chilled noodle': 10,
#  'chinese soup': 11,
#  'chip butty': 12,
#  'cold tofu': 13,
#  'croissant': 14,
#  'croquette': 15,
#  'cutlet curry': 16,
#  'dipping noodles': 17,
#  'dried fish': 18,
#  'eels on rice': 19,
#  'egg roll': 20,
#  'egg sunny-side up': 21,
#  'fermented soybeans': 22,
#  'fish-shaped pancake with bean jam': 23,
#  'french fries': 24,
#  'fried chicken': 25,
#  'fried fish': 26,
#  'fried noodle': 27,
#  'fried rice': 28,
#  'fried shrimp': 29,
#  'ganmodoki': 30,
#  'ginger pork saute': 31,
#  'goya chanpuru': 32,
#  'gratin': 33,
#  'green salad': 34,
#  'grilled eggplant': 35,
#  'grilled pacific saury': 36,
#  'grilled salmon': 37,
#  'hambarg steak': 38,
#  'hamburger': 39,
#  'hot dog': 40,
#  'japanese tofu and vegetable chowder': 41,
#  'japanese-style pancake': 42,
#  'jiaozi': 43,
#  'kinpira-style sauteed burdock': 44,
#  'lightly roasted fish': 45,
#  'macaroni salad': 46,
#  'miso soup': 47,
#  'mixed rice': 48,
#  'nanbanzuke': 49,
#  'oden': 50,
#  'omelet': 51,
#  'omelet with fried rice': 52,
#  'pilaf': 53,
#  'pizza': 54,
#  'pizza toast': 55,
#  'pork cutlet on rice': 56,
#  'pork miso soup': 57,
#  'potage': 58,
#  'potato salad': 59,
#  'raisin bread': 60,
#  'ramen noodle': 61,
#  'rice': 62,
#  'rice ball': 63,
#  'roast chicken': 64,
#  'roll bread': 65,
#  'rolled omelet': 66,
#  'salmon meuniere': 67,
#  'sandwiches': 68,
#  'sashimi': 69,
#  'sashimi bowl': 70,
#  'sausage': 71,
#  'sauteed spinach': 72,
#  'sauteed vegetables': 73,
#  'seasoned beef with potatoes': 74,
#  'shrimp with chill source': 75,
#  'simmered pork': 76,
#  'sirloin cutlet': 77,
#  'soba noodle': 78,
#  'spaghetti': 79,
#  'spaghetti meat sauce': 80,
#  'spicy chili-flavored tofu': 81,
#  'steamed egg hotchpotch': 82,
#  'steamed meat dumpling': 83,
#  'stew': 84,
#  'stir-fried beef and peppers': 85,
#  'sukiyaki': 86,
#  'sushi': 87,
#  'sushi bowl': 88,
#  'sweet and sour pork': 89,
#  'takoyaki': 90,
#  'tempura': 91,
#  'tempura bowl': 92,
#  'tempura udon': 93,
#  'tensin noodle': 94,
#  'teriyaki grilled fish': 95,
#  'toast': 96,
#  'udon noodle': 97,
#  'vegetable tempura': 98,
#  'yakitori': 99}
